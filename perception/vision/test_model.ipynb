# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2
from PIL import Image
import numpy as np
import glob

# Segmentation
# model = YOLO("../../runs/segment/train10/weights/best.pt") # YOLO12
# images = sorted(glob.glob("./datasets/images/sequence/*.jpg"))
# images = sorted(glob.glob("./images/sequence-2/*.png"))

#Detection
model = YOLO("../../runs/detect/train/weights/best.pt") # YOLO12
images = sorted(glob.glob("./datasets/images-grip/sequence/*.jpg"))


for i in range(len(images)):
    result = model(images[i], conf=0.6)[0]
    
    plt.figure(figsize=(10, 8))
    plt.imshow(cv2.cvtColor(result.plot(), cv2.COLOR_BGR2RGB))
    plt.title(images[i])
    plt.axis('off')
    plt.show()
# Out:
# image 1/1 /data/arise/experiments/harmony/perception/vision/datasets/images-grip/sequence/IMG_20251113_160914_200.jpg: 1824x1056 (no detections), 35.8ms
# Speed: 4.9ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 1824, 1056)
# image 1/1 /data/arise/experiments/harmony/perception/vision/datasets/images-grip/sequence/IMG_20251113_160947_075.jpg: 1824x1056 1 cap_grip, 26.5ms
# Speed: 4.6ms preprocess, 26.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1824, 1056)
# image 1/1 /data/arise/experiments/harmony/perception/vision/datasets/images-grip/sequence/IMG_20251113_160951_471.jpg: 1824x1056 (no detections), 26.4ms
# Speed: 4.6ms preprocess, 26.4ms inference, 0.3ms postprocess per image at shape (1, 3, 1824, 1056)
# image 1/1 /data/arise/experiments/harmony/perception/vision/datasets/images-grip/sequence/IMG_20251113_161006_936.jpg: 1824x1056 (no detections), 26.5ms
# ...
